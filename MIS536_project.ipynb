# %% [markdown]
# **What is Rating Area?**
#
# "Under the Affordable Care Act, each state has submitted a plan to divide up the areas of the state into locations called rating areas. Depending on the state these geographical units will either be made up of counties, metropolitan statistical areas or three-digit zip codes. These state groupings will be submitted to The Department of Human Health Services (HHS) for approval and will then be used by insurers to price premiums.
#
# When insurance companies price their premiums, all households within a rating area will have the same adjustment factor applied. Households with similar age and smoking characteristics buying the same plan will pay the same amount for premiums. Depending on the rating area you live in the prices you pay may be higher or lower than the state average.
#
# How Rating Area influences the insured? Insurers determine the factors applied to a rating area based upon the projected cost of members in the specific rating area. These costs may include the costs associated with services providers, how much coverage an insurer has in a particular area, the number of members, as well as the demographic profile of the area. With the limitations on how insurers can determine premiums, rating areas will likely become the key variable in how insurers price groups of people to account for differences in population profiles.
#
# In addition, insurance coverage for particular plans and companies may only be offered in select rating areas. Insurers are not required to offer insurance plans statewide when developing plans and networks for sale on the exchanges. Depending on your area of residence you may have more or less options than is typical of the state." All content from website below.
#
# https://www.valuepenguin.com/what-aca-insurance-ratings-area

# %% [markdown]
# **What is Metal Level**
# Obamacare made it easier to compare health insurance plans by dividing them into four tiers. They fall into categories bronze, silver,gold,platinum. Bronze has the lowest premium and platinum the highest. The difference between them is about what percentage the insurance companies pay and what percentage the insured pay.Read more below.The actuarial cost will show the percentage of the total average costs that the health insurance will pay.For low income individuals below age 30 who have faced a financial hardship the previous year, catastrophic plans are available. They have lower premiums. However, some bronze plans have lower premium and better coverage.
#
# https://www.policygenius.com/health-insurance/what-are-the-metal-tiers/

# %% [markdown]
# What are the dfiferent types of plans
# PPO: Preferred provider Organization
# HMO: Health Maintenance Organization
# POS: Point of Service
#
# See their detailed comparison at https://www.policygenius.com/health-insurance/hmo-ppo-epo-pos-difference/

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('combined_data_BY_METAL_LEVEL.csv')
df.head()
# Out:
#   State County County Type                         Issuer Name   Metal Level  \
# 0    IL  ADAMS       Urban  Blue Cross Blue Shield of Illinois        Bronze
# 1    IL  ADAMS       Urban  Blue Cross Blue Shield of Illinois  Catastrophic
# 2    IL  ADAMS       Urban  Blue Cross Blue Shield of Illinois          Gold
# 3    IL  ADAMS       Urban  Blue Cross Blue Shield of Illinois        Silver
# 4    IL  ADAMS       Urban                Coventry Health Care        Bronze
#
#   Plan Type     Rating Area  Premium Child  Premium Adult Individual Age 21  \
# 0       PPO  Rating Area 10         108.31                           170.57
# 1       PPO  Rating Area 10         104.88                           165.17
# 2       PPO  Rating Area 10         170.28                           268.16
# 3       PPO  Rating Area 10         139.29                           219.36
# 4       PPO  Rating Area 10         110.18                           173.51
#
# ...

# %%
df.columns
# Out:
# Index(['State', 'County', 'County Type', 'Issuer Name', 'Metal Level',
#        'Plan Type', 'Rating Area', 'Premium Child',
#        'Premium Adult Individual Age 21', 'Premium Adult Individual Age 27',
#        'Premium Adult Individual Age 30', 'Premium Adult Individual Age 40',
#        'Premium Adult Individual Age 50', 'Premium Adult Individual Age 60',
#        'Premium Couple 21  ', 'Premium Couple 30', 'Premium Couple 40',
#        'Premium Couple 50', 'Premium Couple 60', 'Couple+1 child, Age 21',
#        'Couple+1 child, Age 30', 'Couple+1 child, Age 40',
#        'Couple+1 child, Age 50', 'Couple+2 children, Age 21',
#        'Couple+2 children, Age 30', 'Couple+2 children, Age 40',
#        'Couple+2 children, Age 50', 'Couple+3 or more Children, Age 21',
#        'Couple+3 or more Children, Age 30',
#        'Couple+3 or more Children, Age 40',
#        'Couple+3 or more Children, Age 50', 'Individual+1 child, Age 21',
# ...

# %%
df.describe()
# Out:
#        Premium Child  Premium Adult Individual Age 21  \
# count    1545.000000                      1545.000000
# mean      140.848913                       221.810751
# std        34.415949                        54.202123
# min        64.020000                       100.820000
# 25%       110.350000                       173.780000
# 50%       139.290000                       219.360000
# 75%       170.280000                       268.160000
# max       232.360000                       365.940000
#
#        Premium Adult Individual Age 27  Premium Adult Individual Age 30  \
# count                      1545.000000                      1545.000000
# mean                        232.453903                       251.754194
# std                          56.799623                        61.517096
# min                         105.660000                       114.430000
# 25%                         182.120000                       197.240000
# ...

# %%
df1=df.groupby(['Rating Area', 'County Type','County','Metal Level','Plan Type']).agg({'Couple+1 child, Age 21': ['mean'],'Couple+1 child, Age 30': ['mean'],'Couple+1 child, Age 50': ['mean']}).reset_index()

# %%
df2=df.groupby(['Rating Area', 'County Type','Metal Level','Plan Type'])[['Couple+1 child, Age 21','Couple+1 child, Age 30','Couple+1 child, Age 50']].agg(['min','mean','max']).reset_index()

# %%
df3=df2[df2['Rating Area']=='Rating Area 2']
df3
# Out:
#       Rating Area County Type   Metal Level Plan Type Couple+1 child, Age 21  \
#                                                                          min
# 64  Rating Area 2       Urban        Bronze       HMO                 487.50
# 65  Rating Area 2       Urban        Bronze       PPO                 500.81
# 66  Rating Area 2       Urban  Catastrophic       HMO                 372.74
# 67  Rating Area 2       Urban  Catastrophic       PPO                 466.00
# 68  Rating Area 2       Urban          Gold       HMO                 636.59
# 69  Rating Area 2       Urban          Gold       PPO                 787.34
# 70  Rating Area 2       Urban      Platinum       HMO                 717.74
# 71  Rating Area 2       Urban      Platinum       PPO                 964.24
# 72  Rating Area 2       Urban        Silver       HMO                 552.85
# 73  Rating Area 2       Urban        Silver       PPO                 644.04
#
# ...

# %% [markdown]
# Common observations
# Age is definitely a critical factor to decide premiums. It is clear from the analysis above that parents in the agegroup of 50 is definitely paing a higher average premium than other younger parents.
# For Rating Area 1
# In the Couple+1 plan, the average prememium for Catastrophic plan for individuals in the agegroup of 30 is lower than that of Bronze plan. For parents in the agegroup 21 also enjoy this benefit of catastrophic plans
# Let's see how the trens changes over rating area and county types.

# %%
df1=df.groupby(['Rating Area', 'County Type','Metal Level','Plan Type']).agg({'Couple+1 child, Age 21': ['mean'],'Couple+1 child, Age 30': ['mean'],'Couple+1 child, Age 50': ['mean']}).reset_index()

# %%
df1.head()
# Out:
#      Rating Area County Type   Metal Level Plan Type Couple+1 child, Age 21  \
#                                                                        mean
# 0  Rating Area 1       Urban        Bronze       HMO               532.5000
# 1  Rating Area 1       Urban        Bronze       PPO               566.9080
# 2  Rating Area 1       Urban  Catastrophic       HMO               407.1300
# 3  Rating Area 1       Urban  Catastrophic       PPO               442.8525
# 4  Rating Area 1       Urban          Gold       HMO               695.3400
#
#   Couple+1 child, Age 30 Couple+1 child, Age 50
#                     mean                   mean
# 0               587.0200               850.1400
# 1               625.2500               905.0280
# 2               448.8300               649.9900
# 3               488.0025               706.4025
# 4               766.5600              1110.1200

# %% [markdown]
# What is Rating Area?
# Under the Affordable Care Act, each state has submitted a plan to divide up the areas of the state into locations called rating areas. Depending on the state these geographical units will either be made up of counties, metropolitan statistical areas or three-digit zip codes. These state groupings will be submitted to The Department of Human Health Services (HHS) for approval and will then be used by insurers to price premiums.
#
# When insurance companies price their premiums, all households within a rating area will have the same adjustment factor applied. Households with similar age and smoking characteristics buying the same plan will pay the same amount for premiums. Depending on the rating area you live in the prices you pay may be higher or lower than the state average.
#
# How Rating Area influences the insured?
# Insurers determine the factors applied to a rating area based upon the projected cost of members in the specific rating area. These costs may include the costs associated with services providers, how much coverage an insurer has in a particular area, the number of members, as well as the demographic profile of the area. With the limitations on how insurers can determine premiums, rating areas will likely become the key variable in how insurers price groups of people to account for differences in population profiles.
#
# In addition, insurance coverage for particular plans and companies may only be offered in select rating areas. Insurers are not required to offer insurance plans statewide when developing plans and networks for sale on the exchanges. Depending on your area of residence you may have more or less options than is typical of the state.
#
# https://www.valuepenguin.com/what-aca-insurance-ratings-area

# %% [markdown]
# #Reference for shape file
# http://clearinghouse.isgs.illinois.edu/data/reference/illinois-county-boundaries-polygons-and-lines
